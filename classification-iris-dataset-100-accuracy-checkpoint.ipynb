# %%
import numpy as np 
import pandas as pd 
import os
# Out:
# /kaggle/input/iris-dataset-uci/Iris.csv

# %%
rootpath=os.getcwd()
datapath=os.path.join(rootpath,"myproject/repository")
flag_path=os.path.join(datapath,"flag.data")

# %%
data = pd.read_csv('/kaggle/input/iris-dataset-uci/Iris.csv')

# %%
data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %% [markdown]
# NAN Values Detect

# %%
data.isna().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
newData = data.drop('Id',axis=1)
X = newData.drop('Species',axis=1)
Y = newData.Species

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size = 0.33, random_state = 15)

# %% [markdown]
# Scale Values

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(x_train)
X_test = scaler.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score

# %% [markdown]
# Logistic Regression

# %%
lr = LogisticRegression()
lr.fit(X_train, y_train)
predictList = lr.predict(X_test)

# %%
print('Accuracy = {} '.format(accuracy_score(lr.predict(X_test), y_test)*100))
# Out:
# Accuracy = 100.0

# %% [markdown]
# Logistic Regression Confusion Matrix

# %%
matrix = confusion_matrix(y_test, predictList)
matrixPd = pd.DataFrame(matrix)
matrixPd
# Out:
#     0   1   2
# 0  17   0   0
# 1   0  17   0
# 2   0   0  16

# %% [markdown]
# Matrix is a Numpy array. Numpy array is can't be a corr. But Pandas array is can be corr.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
cor = matrixPd.corr()

f,ax = plt.subplots(figsize = (5,5))
sns.heatmap(data=cor,annot=True,linewidths=0.5,linecolor="g",ax=ax,fmt=".1f")
plt.show()

# %% [markdown]
# Also Gaussian Naive Bayes And Support Vector Classifier is effective for %100 accuracy.
#
# THANK YOU FOR READING
